# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfx = pd.read_excel(r"C:\Users\ADMIN\Desktop\SOFTWARE.xlsx")

# %%
dfx.head()
# Out:
#      PNAME           TITLE DEVELOPIN    SCOST  DCOST  SOLD
# 0     MARY         README        CPP   300.00   1200    84
# 1    ANAND     PARACHUTES      BASIC   399.95   6000    43
# 2    ANAND   VIDEO TITLING    PASCAL  7500.00  16000     9
# 3  JULIANA       INVENTORY     COBOL  3000.00   3500     0
# 4   KAMALA    PAYROLL PKG.     DBASE  9000.00  20000     7

# %%
dfx[['PNAME','TITLE']]
# Out:
#        PNAME             TITLE
# 0       MARY           README
# 1      ANAND       PARACHUTES
# 2      ANAND     VIDEO TITLING
# 3    JULIANA         INVENTORY
# 4     KAMALA      PAYROLL PKG.
# 5       MARY   FINANCIAL ACCT.
# 6       MARY    CODE GENERATOR
# 7   PATTRICK            README
# 8      QADIR        BOMBS AWAY
# 9      QADIR          VACCINES
# 10    RAMESH       HOTEL MGMT.
# 11    RAMESH          DEAD LEE
# 12   REMITHA      PC UTILITIES
# 13   REMITHA     TSR HELP PKG.
# 14   REVATHI    HOSPITAL MGMT.
# 15    VIJAYA        TSR EDITOR

# %%
df = pd.DataFrame(dfx)

# %%
df.head()
# Out:
#      PNAME           TITLE DEVELOPIN    SCOST  DCOST  SOLD
# 0     MARY         README        CPP   300.00   1200    84
# 1    ANAND     PARACHUTES      BASIC   399.95   6000    43
# 2    ANAND   VIDEO TITLING    PASCAL  7500.00  16000     9
# 3  JULIANA       INVENTORY     COBOL  3000.00   3500     0
# 4   KAMALA    PAYROLL PKG.     DBASE  9000.00  20000     7

# %%
df.loc[df['PNAME'] == 'MARY',['PNAME','TITLE']]
# Out:
#   PNAME             TITLE
# 0  MARY           README
# 5  MARY   FINANCIAL ACCT.
# 6  MARY    CODE GENERATOR

# %%
df.groupby('DEVELOPIN')['SCOST'].mean()
# Out:
# DEVELOPIN
# ASSEMBLY     1625.00
# BASIC         399.95
# C            2006.25
# COBOL        3000.00
# CPP           300.00
# DBASE       11000.00
# ORACLE      18000.00
# PASCAL       3066.65
# Name: SCOST, dtype: float64

# %%
dfx1 = pd.read_excel(r"C:\Users\ADMIN\Desktop\PROGRAMMER.xlsx")

# %%
dfx1.head()
# Out:
#      PNAME        DOB        DOJ GENDER    PROF1   PROF2  SALARY
# 0    ANAND 1966-04-12 1992-04-21      M   PASCAL   BASIC    3200
# 1    ALTAF 1964-07-02 1990-11-13      M  CLIPPER   COBOL    2800
# 2  JULIANA 1960-01-31 1990-04-21      F    COBOL   DBASE    3000
# 3   KAMALA 1968-10-30 1992-01-02      F        C   DBASE    2900
# 4     MARY 1970-06-24 1991-02-01      F      CPP  ORACLE    4500

# %%
df1 = pd.DataFrame(dfx1)

# %%
df1.head()
# Out:
#      PNAME        DOB        DOJ GENDER    PROF1   PROF2  SALARY
# 0    ANAND 1966-04-12 1992-04-21      M   PASCAL   BASIC    3200
# 1    ALTAF 1964-07-02 1990-11-13      M  CLIPPER   COBOL    2800
# 2  JULIANA 1960-01-31 1990-04-21      F    COBOL   DBASE    3000
# 3   KAMALA 1968-10-30 1992-01-02      F        C   DBASE    2900
# 4     MARY 1970-06-24 1991-02-01      F      CPP  ORACLE    4500

# %%
dfx2 = pd.read_excel(r"C:\Users\ADMIN\Desktop\STUDIES.xlsx")

# %%
df2 = pd.DataFrame(dfx2)

# %%
df2.head()
# Out:
#      PNAME INSTITUTE COURSE  COURSE FEE
# 0    ANAND   SABHARI  PGDCA        4500
# 1    ALTAF      COIT    DCA        7200
# 2  JULIANA      BDPS    MCA       22000
# 3   KAMALA  PRAGATHI    DCA        5000
# 4     MARY   SABHARI  PGDCA        4500

# %%
df2.loc[df2['COURSE'] == 'DCA', ['PNAME','COURSE']]
# Out:
#      PNAME COURSE
# 1    ALTAF    DCA
# 3   KAMALA    DCA
# 12  VIJAYA    DCA

# %%
df.loc[df['PNAME'] == 'RAMESH', ['PNAME','TITLE','DEVELOPIN','SCOST','DCOST']]
# Out:
#      PNAME         TITLE DEVELOPIN     SCOST  DCOST
# 10  RAMESH   HOTEL MGMT.     DBASE  13000.00  35000
# 11  RAMESH      DEAD LEE    PASCAL    599.95   4500

# %%
df.loc[(df['SCOST']-df['DCOST']*df['SOLD']) < 0 ,['TITLE']]
# Out:
#                TITLE
# 0            README
# 1        PARACHUTES
# 2      VIDEO TITLING
# 4       PAYROLL PKG.
# 5    FINANCIAL ACCT.
# 6     CODE GENERATOR
# 7             README
# 8         BOMBS AWAY
# 9           VACCINES
# 10       HOTEL MGMT.
# 11          DEAD LEE
# 12      PC UTILITIES
# 13     TSR HELP PKG.
# 14    HOSPITAL MGMT.
# 15        TSR EDITOR

# %%
df1.loc[(df1['PROF1']=='C') | (df1['PROF2']=='C'), ['PNAME']]
# Out:
#       PNAME
# 3    KAMALA
# 7     QADIR
# 10  REMITHA
# 12   VIJAYA

# %%
df1.head()
# Out:
#      PNAME        DOB        DOJ GENDER    PROF1   PROF2  SALARY
# 0    ANAND 1966-04-12 1992-04-21      M   PASCAL   BASIC    3200
# 1    ALTAF 1964-07-02 1990-11-13      M  CLIPPER   COBOL    2800
# 2  JULIANA 1960-01-31 1990-04-21      F    COBOL   DBASE    3000
# 3   KAMALA 1968-10-30 1992-01-02      F        C   DBASE    2900
# 4     MARY 1970-06-24 1991-02-01      F      CPP  ORACLE    4500

# %%
df1.loc[df1['GENDER']=='M', ['PROF1','PROF2']]
# Out:
#       PROF1    PROF2
# 0    PASCAL    BASIC
# 1   CLIPPER    COBOL
# 5     COBOL    DBASE
# 6    PASCAL  CLIPPER
# 7  ASSEMBLY        C
# 8    PASCAL    DBASE

# %%
MaxSold = df['SOLD'].max()

# %%
df[df['SOLD'] == MaxSold]['TITLE']
# Out:
# 0     README
# 7      README
# Name: TITLE, dtype: object

# %%
MinFee = df2['COURSE FEE'].min()
df2[df2['COURSE FEE']==MinFee][['COURSE','COURSE FEE']].head(1)
# Out:
#   COURSE  COURSE FEE
# 0  PGDCA        4500

# %%
df1.loc[df1['GENDER']=='F']
# Out:
#       PNAME        DOB        DOJ GENDER   PROF1     PROF2  SALARY
# 2   JULIANA 1960-01-31 1990-04-21      F   COBOL     DBASE    3000
# 3    KAMALA 1968-10-30 1992-01-02      F       C     DBASE    2900
# 4      MARY 1970-06-24 1991-02-01      F     CPP    ORACLE    4500
# 9   REBECCA 1967-01-01 1990-12-01      F   BASIC     COBOL    2500
# 10  REMITHA 1970-04-19 1993-04-20      F       C  ASSEMBLY    3600
# 11  REVATHI 1969-12-02 1992-01-02      F  PASCAL     BASIC    3700
# 12   VIJAYA 1965-12-14 1992-05-02      F  FOXPRO         C    3500

# %%
df2.loc[df2['COURSE'] == 'PGDCA','PNAME'].count()
# Out:
# 3

# %%
df1['SALARY'].mean()
# Out:
# 3169.230769230769

# %%
df1.loc[(df1['SALARY']>=2000) & (df1['SALARY']<=4000),['PNAME','SALARY']]
# Out:
#        PNAME  SALARY
# 0      ANAND    3200
# 1      ALTAF    2800
# 2    JULIANA    3000
# 3     KAMALA    2900
# 5     NELSON    2500
# 6   PATTRICK    2800
# 7      QADIR    3000
# 8     RAMESH    3200
# 9    REBECCA    2500
# 10   REMITHA    3600
# 11   REVATHI    3700
# 12    VIJAYA    3500

# %%
df1.loc[(df1['PROF1']=='COBOL') | (df1['PROF2']=='COBOL') | (df1['PROF1']=='PASCAL') | (df1['PROF2']=='PASCAL'), ['PNAME','PROF1','PROF2']]
# Out:
#        PNAME    PROF1    PROF2
# 0      ANAND   PASCAL    BASIC
# 1      ALTAF  CLIPPER    COBOL
# 2    JULIANA    COBOL    DBASE
# 5     NELSON    COBOL    DBASE
# 6   PATTRICK   PASCAL  CLIPPER
# 8     RAMESH   PASCAL    DBASE
# 9    REBECCA    BASIC    COBOL
# 11   REVATHI   PASCAL    BASIC

# %%
df1.loc[df1['GENDER'] == 'F','PNAME'].count()
# Out:
# 7

# %%
df2.loc[df2['INSTITUTE']=='PRAGATHI', ['PNAME']]
# Out:
#      PNAME
# 3   KAMALA
# 5   NELSON
# 6  PATRICK

# %%
tempdf1 =pd.DataFrame(df1.groupby('PROF1').filter(lambda x: len(x) ==1)['PROF1'])
tempdf1.rename(columns={'PROF1':'PROF'}, inplace = True)
print(tempdf1)
# Out:
#         PROF
# 1    CLIPPER
# 4        CPP
# 7   ASSEMBLY
# 9      BASIC
# 12    FOXPRO

# %%
tempdf2 = pd.DataFrame(df1.groupby('PROF2').filter(lambda x: len(x) ==1)['PROF2'])
tempdf2.rename(columns={'PROF2':'PROF'}, inplace = True)
print(tempdf2)
# Out:
#         PROF
# 4     ORACLE
# 6    CLIPPER
# 10  ASSEMBLY

# %%
merged = tempdf1.merge(tempdf2, on='PROF', how = 'outer', indicator = True)
single_merged = merged[merged['_merge'] != 'both']['PROF']
print(single_merged)
# Out:
# 1       CPP
# 3     BASIC
# 4    FOXPRO
# 5    ORACLE
# Name: PROF, dtype: object

# %%
df.head()
# Out:
#      PNAME           TITLE DEVELOPIN    SCOST  DCOST  SOLD
# 0     MARY         README        CPP   300.00   1200    84
# 1    ANAND     PARACHUTES      BASIC   399.95   6000    43
# 2    ANAND   VIDEO TITLING    PASCAL  7500.00  16000     9
# 3  JULIANA       INVENTORY     COBOL  3000.00   3500     0
# 4   KAMALA    PAYROLL PKG.     DBASE  9000.00  20000     7

# %%
df.sort_values(by = 'DEVELOPIN', ascending = True)[['DEVELOPIN','PNAME','TITLE']]
# Out:
#    DEVELOPIN     PNAME             TITLE
# 8   ASSEMBLY     QADIR        BOMBS AWAY
# 13  ASSEMBLY   REMITHA     TSR HELP PKG.
# 1      BASIC     ANAND       PARACHUTES
# 6          C      MARY    CODE GENERATOR
# 9          C     QADIR          VACCINES
# 12         C   REMITHA      PC UTILITIES
# 15         C    VIJAYA        TSR EDITOR
# 3      COBOL   JULIANA         INVENTORY
# 0        CPP      MARY           README
# 7        CPP  PATTRICK            README
# 4      DBASE    KAMALA      PAYROLL PKG.
# 10     DBASE    RAMESH       HOTEL MGMT.
# 5     ORACLE      MARY   FINANCIAL ACCT.
# 2     PASCAL     ANAND     VIDEO TITLING
# 11    PASCAL    RAMESH          DEAD LEE
# 14    PASCAL   REVATHI    HOSPITAL MGMT.

# %%
Lang_Title = df.groupby('DEVELOPIN')['TITLE'].value_counts()
print(Lang_Title)
# Out:
# DEVELOPIN  TITLE
# ASSEMBLY    BOMBS AWAY         1
#             TSR HELP PKG.      1
# BASIC       PARACHUTES         1
# C           CODE GENERATOR     1
#             PC UTILITIES       1
#             TSR EDITOR         1
#             VACCINES           1
# COBOL       INVENTORY          1
# CPP         README             1
#             README             1
# DBASE       HOTEL MGMT.        1
#             PAYROLL PKG.       1
# ORACLE      FINANCIAL ACCT.    1
# PASCAL      DEAD LEE           1
#             HOSPITAL MGMT.     1
#             VIDEO TITLING      1
# Name: TITLE, dtype: int64

# %%
df.groupby('DEVELOPIN')['TITLE'].count().idxmax()
# Out:
# 'C'

# %%
df.groupby('DEVELOPIN')['TITLE'].count().max()
# Out:
# 4

# %%
sal = df1.loc[df1['SALARY']>=2000, ['SALARY']]

# %%
sal.mean()
# Out:
# SALARY    3169.230769
# dtype: float64

# %%
cost = df.loc[df['SCOST']<1000, ['TITLE','DEVELOPIN']]

# %%
cost.groupby('DEVELOPIN')['TITLE'].value_counts()
# Out:
# DEVELOPIN  TITLE
# ASSEMBLY    BOMBS AWAY      1
# BASIC       PARACHUTES      1
# C           PC UTILITIES    1
#             TSR EDITOR      1
# CPP         README          1
#             README          1
# PASCAL      DEAD LEE        1
# Name: TITLE, dtype: int64

# %%
df1.head()
# Out:
#      PNAME        DOB        DOJ GENDER    PROF1   PROF2  SALARY
# 0    ANAND 1966-04-12 1992-04-21      M   PASCAL   BASIC    3200
# 1    ALTAF 1964-07-02 1990-11-13      M  CLIPPER   COBOL    2800
# 2  JULIANA 1960-01-31 1990-04-21      F    COBOL   DBASE    3000
# 3   KAMALA 1968-10-30 1992-01-02      F        C   DBASE    2900
# 4     MARY 1970-06-24 1991-02-01      F      CPP  ORACLE    4500

# %%
df1.loc[(df1['PROF1']!= 'PASCAL') & (df1['PROF2']!= 'C') & (df1['PROF2']!= 'PASCAL') & (df1['PROF1']!= 'C' ), ['PNAME']]
# Out:
#      PNAME
# 1    ALTAF
# 2  JULIANA
# 4     MARY
# 5   NELSON
# 9  REBECCA

# %%
df1
# Out:
#        PNAME        DOB        DOJ GENDER     PROF1     PROF2  SALARY
# 0      ANAND 1966-04-12 1992-04-21      M    PASCAL     BASIC    3200
# 1      ALTAF 1964-07-02 1990-11-13      M   CLIPPER     COBOL    2800
# 2    JULIANA 1960-01-31 1990-04-21      F     COBOL     DBASE    3000
# 3     KAMALA 1968-10-30 1992-01-02      F         C     DBASE    2900
# 4       MARY 1970-06-24 1991-02-01      F       CPP    ORACLE    4500
# 5     NELSON 1985-09-11 1989-10-11      M     COBOL     DBASE    2500
# 6   PATTRICK 1965-11-10 1990-04-21      M    PASCAL   CLIPPER    2800
# 7      QADIR 1965-08-31 1991-04-21      M  ASSEMBLY         C    3000
# 8     RAMESH 1967-05-03 1991-02-28      M    PASCAL     DBASE    3200
# 9    REBECCA 1967-01-01 1990-12-01      F     BASIC     COBOL    2500
# 10   REMITHA 1970-04-19 1993-04-20      F         C  ASSEMBLY    3600
# 11   REVATHI 1969-12-02 1992-01-02      F    PASCAL     BASIC    3700
# ...

# %%
df.head()
# Out:
#      PNAME           TITLE DEVELOPIN    SCOST  DCOST  SOLD
# 0     MARY         README        CPP   300.00   1200    84
# 1    ANAND     PARACHUTES      BASIC   399.95   6000    43
# 2    ANAND   VIDEO TITLING    PASCAL  7500.00  16000     9
# 3  JULIANA       INVENTORY     COBOL  3000.00   3500     0
# 4   KAMALA    PAYROLL PKG.     DBASE  9000.00  20000     7

# %%
df.groupby('DEVELOPIN')[['SCOST']].mean()
# Out:
#               SCOST
# DEVELOPIN
# ASSEMBLY    1625.00
# BASIC        399.95
# C           2006.25
# COBOL       3000.00
# CPP          300.00
# DBASE      11000.00
# ORACLE     18000.00
# PASCAL      3066.65

# %%
df
# Out:
#        PNAME             TITLE DEVELOPIN     SCOST  DCOST  SOLD
# 0       MARY           README        CPP    300.00   1200    84
# 1      ANAND       PARACHUTES      BASIC    399.95   6000    43
# 2      ANAND     VIDEO TITLING    PASCAL   7500.00  16000     9
# 3    JULIANA         INVENTORY     COBOL   3000.00   3500     0
# 4     KAMALA      PAYROLL PKG.     DBASE   9000.00  20000     7
# 5       MARY   FINANCIAL ACCT.    ORACLE  18000.00  85000     4
# 6       MARY    CODE GENERATOR         C   4500.00  20000    23
# 7   PATTRICK            README       CPP    300.00   1200    84
# 8      QADIR        BOMBS AWAY  ASSEMBLY    750.00   3000    11
# 9      QADIR          VACCINES         C   1900.00   3100    21
# 10    RAMESH       HOTEL MGMT.     DBASE  13000.00  35000     4
# 11    RAMESH          DEAD LEE    PASCAL    599.95   4500    73
# 12   REMITHA      PC UTILITIES         C    725.00   5000    51
# 13   REMITHA     TSR HELP PKG.  ASSEMBLY   2500.00   6000     7
# ...

# %%
df.groupby('DEVELOPIN')[['DCOST','SCOST','SOLD']].mean()
# Out:
#                   DCOST     SCOST   SOLD
# DEVELOPIN
# ASSEMBLY    4500.000000   1625.00   9.00
# BASIC       6000.000000    399.95  43.00
# C           7200.000000   2006.25  25.25
# COBOL       3500.000000   3000.00   0.00
# CPP         1200.000000    300.00  84.00
# DBASE      27500.000000  11000.00   5.50
# ORACLE     85000.000000  18000.00   4.00
# PASCAL     31833.333333   3066.65  28.00

# %%
df.groupby('PNAME')[['TITLE']].count()
# Out:
#           TITLE
# PNAME
# ANAND         2
# JULIANA       1
# KAMALA        1
# MARY          3
# PATTRICK      1
# QADIR         2
# RAMESH        2
# REMITHA       2
# REVATHI       1
# VIJAYA        1

# %%
df.groupby('DEVELOPIN').apply(lambda x: x['SCOST']*x['SOLD']-x['DCOST'])
# Out:
# DEVELOPIN
# ASSEMBLY   8      5250.00
#            13    11500.00
# BASIC      1     11197.85
# C          6     83500.00
#            9     36800.00
#            12    31975.00
#            15     4700.00
# COBOL      3     -3500.00
# CPP        0     24000.00
#            7     24000.00
# DBASE      4     43000.00
#            10    17000.00
# ORACLE     5    -13000.00
# PASCAL     2     51500.00
#            11    39296.35
#            14   -72800.00
# dtype: float64

# %%
max_dcost = df['DCOST'].max()
max_dcost_name = df.loc[df['DCOST']==max_dcost, 'PNAME'].iloc[0]
max_dcost_name
# Out:
# 'MARY'

# %%
df2.loc[df2['PNAME']==max_dcost_name, 'INSTITUTE'].iloc[0]
# Out:
# 'SABHARI'

# %%
df1.loc[df1['PNAME']
# Out:
# 0        ANAND
# 1        ALTAF
# 2      JULIANA
# 3       KAMALA
# 4         MARY
# 5       NELSON
# 6     PATTRICK
# 7        QADIR
# 8       RAMESH
# 9      REBECCA
# 10     REMITHA
# 11     REVATHI
# 12      VIJAYA
# Name: PNAME, dtype: object

# %%
prog_name = df.merge(df1, on='PNAME', how='outer', indicator=True)
prog_name
# Out:
#        PNAME             TITLE DEVELOPIN     SCOST    DCOST  SOLD        DOB  \
# 0       MARY           README        CPP    300.00   1200.0  84.0 1970-06-24
# 1       MARY   FINANCIAL ACCT.    ORACLE  18000.00  85000.0   4.0 1970-06-24
# 2       MARY    CODE GENERATOR         C   4500.00  20000.0  23.0 1970-06-24
# 3      ANAND       PARACHUTES      BASIC    399.95   6000.0  43.0 1966-04-12
# 4      ANAND     VIDEO TITLING    PASCAL   7500.00  16000.0   9.0 1966-04-12
# 5    JULIANA         INVENTORY     COBOL   3000.00   3500.0   0.0 1960-01-31
# 6     KAMALA      PAYROLL PKG.     DBASE   9000.00  20000.0   7.0 1968-10-30
# 7   PATTRICK            README       CPP    300.00   1200.0  84.0 1965-11-10
# 8      QADIR        BOMBS AWAY  ASSEMBLY    750.00   3000.0  11.0 1965-08-31
# 9      QADIR          VACCINES         C   1900.00   3100.0  21.0 1965-08-31
# 10    RAMESH       HOTEL MGMT.     DBASE  13000.00  35000.0   4.0 1967-05-03
# ...

# %%
prog_name.loc[prog_name['_merge'] == 'right_only',['PNAME']]
# Out:
#       PNAME
# 16    ALTAF
# 17   NELSON
# 18  REBECCA

# %%
df
# Out:
#        PNAME             TITLE DEVELOPIN     SCOST  DCOST  SOLD
# 0       MARY           README        CPP    300.00   1200    84
# 1      ANAND       PARACHUTES      BASIC    399.95   6000    43
# 2      ANAND     VIDEO TITLING    PASCAL   7500.00  16000     9
# 3    JULIANA         INVENTORY     COBOL   3000.00   3500     0
# 4     KAMALA      PAYROLL PKG.     DBASE   9000.00  20000     7
# 5       MARY   FINANCIAL ACCT.    ORACLE  18000.00  85000     4
# 6       MARY    CODE GENERATOR         C   4500.00  20000    23
# 7   PATTRICK            README       CPP    300.00   1200    84
# 8      QADIR        BOMBS AWAY  ASSEMBLY    750.00   3000    11
# 9      QADIR          VACCINES         C   1900.00   3100    21
# 10    RAMESH       HOTEL MGMT.     DBASE  13000.00  35000     4
# 11    RAMESH          DEAD LEE    PASCAL    599.95   4500    73
# 12   REMITHA      PC UTILITIES         C    725.00   5000    51
# 13   REMITHA     TSR HELP PKG.  ASSEMBLY   2500.00   6000     7
# ...

# %%
t1 = df.merge(df1, left_on='DEVELOPIN', right_on='PROF1', how='outer', indicator =True)
tab1 = t1.loc[t1['_merge']=='right_only', ['PROF1']]
tab1
# Out:
#       PROF1
# 30  CLIPPER
# 31   FOXPRO

# %%
t2 = df.merge(df1, left_on='DEVELOPIN', right_on='PROF2', how='outer', indicator =True)
tab2 = t2.loc[t2['_merge']=='right_only', ['PROF2']]

# %%
tab1.merge(tab2, left_on='PROF1', right_on='PROF2', how="outer")
# Out:
#      PROF1    PROF2
# 0  CLIPPER  CLIPPER
# 1   FOXPRO      NaN

# %%
df
# Out:
#        PNAME             TITLE DEVELOPIN     SCOST  DCOST  SOLD
# 0       MARY           README        CPP    300.00   1200    84
# 1      ANAND       PARACHUTES      BASIC    399.95   6000    43
# 2      ANAND     VIDEO TITLING    PASCAL   7500.00  16000     9
# 3    JULIANA         INVENTORY     COBOL   3000.00   3500     0
# 4     KAMALA      PAYROLL PKG.     DBASE   9000.00  20000     7
# 5       MARY   FINANCIAL ACCT.    ORACLE  18000.00  85000     4
# 6       MARY    CODE GENERATOR         C   4500.00  20000    23
# 7   PATTRICK            README       CPP    300.00   1200    84
# 8      QADIR        BOMBS AWAY  ASSEMBLY    750.00   3000    11
# 9      QADIR          VACCINES         C   1900.00   3100    21
# 10    RAMESH       HOTEL MGMT.     DBASE  13000.00  35000     4
# 11    RAMESH          DEAD LEE    PASCAL    599.95   4500    73
# 12   REMITHA      PC UTILITIES         C    725.00   5000    51
# 13   REMITHA     TSR HELP PKG.  ASSEMBLY   2500.00   6000     7
# ...

# %%
t_pkg = df.groupby('PNAME')['TITLE'].count()
df_pkg = pd.DataFrame(t_pkg)
df_pkg
# Out:
#           TITLE
# PNAME
# ANAND         2
# JULIANA       1
# KAMALA        1
# MARY          3
# PATTRICK      1
# QADIR         2
# RAMESH        2
# REMITHA       2
# REVATHI       1
# VIJAYA        1

# %%
res = df2.merge(df_pkg, left_on ='PNAME', right_on = 'PNAME', how = "inner")
res[['PNAME','INSTITUTE','TITLE']]
# Out:
#      PNAME INSTITUTE  TITLE
# 0    ANAND   SABHARI      2
# 1  JULIANA      BDPS      1
# 2   KAMALA  PRAGATHI      1
# 3     MARY   SABHARI      3
# 4    QADIR     APPLE      2
# 5   RAMESH   SABHARI      2
# 6  REMITHA      BDPS      2
# 7  REVATHI   SABHARI      1
# 8   VIJAYA      BDPS      1

# %%
df1.loc[df1['SALARY']>=3000, ['PNAME','SALARY']]
# Out:
#       PNAME  SALARY
# 0     ANAND    3200
# 2   JULIANA    3000
# 4      MARY    4500
# 7     QADIR    3000
# 8    RAMESH    3200
# 10  REMITHA    3600
# 11  REVATHI    3700
# 12   VIJAYA    3500
